# %%
# %pylab inline
plt.style.use('dark_background')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from os.path import join

# %%
# %run ../tools/echelle.py
cb = Calibrations('../calibration_files')

# %%
cb.start()

# %%
# %run ../tools/echelle.py

#pth = '../calibration_files/absolute_20170613_b8_0.2_v2.sif'
#pth = r'C:\Users\queez\Dropbox\DataSvn\#LHD\Raw_images\20170714\142441_Echelle.SIF'
pth = r'C:\Users\queez\Dropbox\DataSvn\#LHD\Raw_images\20170707\142365_Echelle.SIF'
em = EchelleImage(pth,clbr=cb)

# %%
em.calculate_order_spectra()
print(em.order_spectra.shape)
a = em.order_spectra.copy()
em.correct_order_shapes()
print(em.order_spectra.shape)
b = em.order_spectra.copy()
# Out:
# (30, 28, 1024)
# (30, 28, 1024)

# %%
frame = 3
o = 6
plot(a[frame,o],lw=4,label='asis')
plot(b[frame,o],lw=2,ls='-',label='corrected')
legend()

# %%
em.calculate_order_spectra()
em.correct_order_shapes()
em.calculate_spectra()
#em.plot_order_image(28,6,20)

# %%
frame = 7
em.plot_cut_image(frame,2)
gcf().set_size_inches(10,10)
#savefig('CCD_cut.png',dvi=300,pad_inches=0,bbox_inches='tight')

# %%
em.plot_order_image(7,27,10)

# %%
plot(em.order_spectra[7,27,:])

# %%
s = Spectrum(em)

# %%
frame = 6
x = s.wavelength
y = s.spectra_to_save['wm'][frame]
plot(x,y)

# %%
plot(x)
