# %% [markdown]
# # Load images from new Echelle

# %% [markdown]
# ## Imports and Setup

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import os
import plotly.graph_objects as go
from lmfit.models import GaussianModel
from ipywidgets import interact,widgets
from intersect import intersection

# %%
# Don't know how to import locally, so I just use %run
# %run ../tools/echelle.py

# %%
files_cmos = {
    "orders": "pattern_cmos.txt",
    "wavelength": "Th_wavelength_CMOS.txt",
    "sphr": "sphere_CMOS.sif",
    "bkgr": "sphere_CMOS_bkg.sif",
    "integral": "integrating_sphere.txt",
}
files_ccd = {
    "orders": "pattern.txt",
    "wavelength": "Th_wavelength.txt",
    "sphr": "absolute_20170613_b8_0.2_v2.sif",
    "bkgr": "absolute_20170613_b8_0.2_bkg.sif",
    "integral": "integrating_sphere.txt",
}
bpth = '../resources/calibration_files'

# %%
# %run ../tools/echelle.py
cb = Calibrations(bpth,files_cmos)
cb.start()

# %%
plt.imshow(cb.order_borders,aspect=60,origin='lower')

# %%
th = EchelleImage(os.path.join(bpth,'ThAr_10.0s_16bit.sif'),clbr=cb)
th.calculate_order_spectra()
th.calculate_spectra()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\queez\Dropbox\workspace\echelle_fujii\echelle_spectra\src\echelle_spectra\examples\3.5_Load_Black_Echelle.ipynb Cell 8 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/queez/Dropbox/workspace/echelle_fujii/echelle_spectra/src/echelle_spectra/examples/3.5_Load_Black_Echelle.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> th = EchelleImage(os.path.join(bpth,'ThAr_10.0s_16bit.sif'),clbr=cb)
#       <a href='vscode-notebook-cell:/c%3A/Users/queez/Dropbox/workspace/echelle_fujii/echelle_spectra/src/echelle_spectra/examples/3.5_Load_Black_Echelle.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> th.calculate_order_spectra()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/queez/Dropbox/workspace/echelle_fujii/echelle_spectra/src/echelle_spectra/examples/3.5_Load_Black_Echelle.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> th.calculate_spectra()
#
# File ~\Dropbox\workspace\echelle_fujii\echelle_spectra\src\echelle_spectra\tools\echelle.py:275, in EchelleImage.calculate_spectra(self)
#     270 """calculate continuous spectra from order_spectra
#     271 using order borders from calibration clbr
#     272 """
#     273 clbr = self.clbr
# --> 275 self.spectra = np.array([i[clbr.order_borders] for i in self.order_spectra])
#     277 a = remove_npnans(self.spectra)
#     279 self.spectra = a.reshape(self.info["NumberOfFrames"], int(len(a) / self.info["NumberOfFrames"]))
#
# File ~\Dropbox\workspace\echelle_fujii\echelle_spectra\src\echelle_spectra\tools\echelle.py:275, in <listcomp>(.0)
#     270 """calculate continuous spectra from order_spectra
#     271 using order borders from calibration clbr
#     272 """
#     273 clbr = self.clbr
# --> 275 self.spectra = np.array([i[clbr.order_borders] for i in self.order_spectra])
#     277 a = remove_npnans(self.spectra)
#     279 self.spectra = a.reshape(self.info["NumberOfFrames"], int(len(a) / self.info["NumberOfFrames"]))
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
np.array([i[cb.order_borders] for i in th.order_spectra[0]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\queez\Dropbox\workspace\echelle_fujii\echelle_spectra\src\echelle_spectra\examples\3.5_Load_Black_Echelle.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/queez/Dropbox/workspace/echelle_fujii/echelle_spectra/src/echelle_spectra/examples/3.5_Load_Black_Echelle.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> np.array([i[cb.order_borders] for i in th.order_spectra[0]])
#
# c:\Users\queez\Dropbox\workspace\echelle_fujii\echelle_spectra\src\echelle_spectra\examples\3.5_Load_Black_Echelle.ipynb Cell 9 in <listcomp>(.0)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/queez/Dropbox/workspace/echelle_fujii/echelle_spectra/src/echelle_spectra/examples/3.5_Load_Black_Echelle.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> np.array([i[cb.order_borders] for i in th.order_spectra[0]])
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
spec0 = th.order_spectra[0][0]
w = cb.order_wavel[0]
plt.plot(w,spec0)

# %%
# Out:
# array([803.03470821, 803.02198553, 803.00926269, ..., 769.99878497,
#        769.98566791, 769.97255069])

# %%
x = th.wavelength
y = th.spectra[0]

pg_data = [go.Scatter(x=x,y=y,name = 'a')]
fig = go.Figure(data=pg_data)
fig.update_layout(template='plotly_white')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\queez\Dropbox\workspace\echelle_fujii\echelle_spectra\src\echelle_spectra\examples\3.5_Load_Black_Echelle.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/queez/Dropbox/workspace/echelle_fujii/echelle_spectra/src/echelle_spectra/examples/3.5_Load_Black_Echelle.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> x = th.wavelength
#       <a href='vscode-notebook-cell:/c%3A/Users/queez/Dropbox/workspace/echelle_fujii/echelle_spectra/src/echelle_spectra/examples/3.5_Load_Black_Echelle.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> y = th.spectra[0]
#       <a href='vscode-notebook-cell:/c%3A/Users/queez/Dropbox/workspace/echelle_fujii/echelle_spectra/src/echelle_spectra/examples/3.5_Load_Black_Echelle.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> pg_data = [go.Scatter(x=x,y=y,name = 'a')]
#
# AttributeError: 'EchelleImage' object has no attribute 'wavelength'

# %%
sp = Spectrum(h2)
plt.plot(sp.wavelength,sp.wm[0])

# %%
plt.imshow(cb.order_borders,aspect=40)

# %%
def isc(x1, y1, x2, y2):
    """For two neighbor orders with lambda \propto -pix
    find end index for x1 and start index for x2 so they will
    not intersect
    x1 < ind1 and x2 >= ind2
    """
    from scipy.interpolate import interp1d

    # remove np.nan from vectors
    i1 = ~np.isnan(x1)
    i2 = ~np.isnan(x2)
    x1 = x1[i1]
    y1 = y1[i1]
    x2 = x2[i2]
    y2 = y2[i2]

    f1 = interp1d(x1, y1, 1)
    f2 = interp1d(x2, y2, 1)
    x = np.linspace(*sorted([x1[0], x1[-1], x2[0], x2[-1]])[1:-1], len(x2))
    x0 = x[np.argmin(np.abs(f1(x) - f2(x)))]
    ind2 = np.where(x2 <= x0)
    ind1 = np.where(x1 > x0)

    return ind1[0][-1] + 1, ind2[0][0]

# %%
o = 2
isc(
    h2.clbr.order_wavel[o],
    h2.clbr.sphr.order_spectra[0, o],
    h2.clbr.order_wavel[o + 1],
    h2.clbr.sphr.order_spectra[0, o + 1],
)
# Out:
# (2304, 0)

# %%
o = 2
x1 = h2.clbr.order_wavel[o]
y1 = h2.clbr.sphr.order_spectra[0, o]
x2 = h2.clbr.order_wavel[o + 1]
y2 = h2.clbr.sphr.order_spectra[0, o + 1]
x,y = intersection(x1,y1,x2,y2)
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x,y,'*k')

# %%
from scipy.interpolate import interp1d

o = 2
x1 = h2.clbr.order_wavel[o]
y1 = h2.clbr.sphr.order_spectra[0, o]
x2 = h2.clbr.order_wavel[o + 1]
y2 = h2.clbr.sphr.order_spectra[0, o + 1]
if x1[0]<x2[0]:
    # swap places
    print(x1[0],x2[0])
    a,b = x1,y1
    x1,y1 = x2,y2
    x2,y2 = a,b
# remove np.nan from vectors
i1 = ~np.isnan(x1)
i2 = ~np.isnan(x2)
x1 = x1[i1]
y1 = y1[i1]
x2 = x2[i2]
y2 = y2[i2]

f1 = interp1d(x1, y1, 1)
f2 = interp1d(x2, y2, 1)
x = np.linspace(*sorted([x1[0], x1[-1], x2[0], x2[-1]])[1:-1], len(x2))
x0 = x[np.argmin(np.abs(f1(x) - f2(x)))]
ind2 = np.where(x2 <= x0)
ind1 = np.where(x1 > x0)

ind1[0][0] + 1, ind2[0][-1]
# Out:
# 582.8098122366777 588.9391376588179
# (627, 1572)

# %%
#plt.plot(x,f1(x),label='1')
#plt.plot(x,f2(x),label='2')
#plt.plot(x,np.abs(f1(x)-f2(x)))
#plt.axvline(x0,c='k')
plt.plot(x2[ind2],y2[ind2],'-.',label='ind2')
plt.plot(x1[ind1],y1[ind1],'-.',label='ind1')
plt.legend()

# %%
x1[0]>x2[0]
# Out:
# True

# %%
plt.plot(x1)
plt.plot(x2)

# %%
for o in range(12):
    plt.plot(h2.clbr.order_wavel[o],h2.clbr.sphr.order_spectra[0, o])
    plt.plot(h2.clbr.order_wavel[o + 1],h2.clbr.sphr.order_spectra[0, o + 1])
